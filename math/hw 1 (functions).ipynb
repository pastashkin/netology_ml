# %% [markdown]
# <a href="https://colab.research.google.com/github/yustinaivanova/math_netology/blob/master/dz_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Математики для data science.
# # Домашнее задание 1.

# %% [markdown]
# **Задание на отображение множеств.**

# %% [markdown]
# **Задание 1.**

# %% [markdown]
# Написать функцию отображения элементов одного множества в другое. Первое множество - художники, второе множество - картины художников.
# Множество художников - Серов, Левитан, Репин, Васнецов, Шишкин.
# Множество картин - "Утро в сосновом бору", "Богатыри", "Золотая осень", "Девочка с персиками", "Запорожцы", "Буралки на Волге", "Март", "Алёнушка".

# %%
def painters_paintings(painter):
    painters_paintings_dictionary = {
        'Серов': ['Девочка с персиками'],
        'Левитан': ['Золотая осень', 'Март'],
        'Репин': ['Запорожцы', 'Буралки на Волге'],
        'Васнецов': ['Богатыри', 'Алёнушка'],
        'Шишкин': ['Утро в сосновом бору']
    }
    try: 
        return painters_paintings_dictionary[painter]
    except:
        return print('No such painter.')

# %%
painters_paintings('Васнецов')
# Out:
# ['Богатыри', 'Алёнушка']

# %% [markdown]
# **Полиномиальные функции.**

# %% [markdown]
# **Задание 2**. Найти из следующих функций те, которые являются полиномиальной функцией.

# %% [markdown]
# Из определения, целая рациональная функция (также полиномиальная функция) имеет вид
# $$f(x) = \sum\limits_{i=0}^n a_ix^i$$
# где: $n \in \mathbb{N}$, $a_n, a_{n-1}, ... a_0 \in \mathbb{R}$ , $a_n \neq 0$

# %% [markdown]
# *  $$полином: f(x)=\frac{1}{2}x^{6}-1\frac{5}{6}x+\frac{1}{3}$$
# *  $$нет: f(x)=\frac{3x^{6}-11x+2}{6}$$
# *  $$нет: f(x)=\frac{3x^{6}-11x+2}{6x}$$
# *  $$нет: f(x)=x^{5}-3x^{2}+7x^{-2}$$
# *  $$полином: f(x)=(5x^{2}-2)^3-\frac{1}{2}x^{3}$$
# *  $$нет: f(x)=(1+\sqrt{x})^{3}-5(1+\sqrt{x})$$
# *  $$полином: f(x)=\pi $$

# %% [markdown]
# **Задание 3**. Раскрыть скобки для следующего полинома $$(2x+1)^{2}(x-1)-x(4x^{2}-1)-x(4x^{2}-1)=ax^3+bx^2+cx+d$$ найти коэффициенты для a, b, c, d.

# %% [markdown]
# Для данного задания полезно использовать следующие формулы сокращенного умножения:
# ![alt text](https://sun9-38.userapi.com/c851232/v851232044/19c5b0/7Yy6qz-MUHA.jpg)

# %% [markdown]
# Чему равна степень полинома?

# %% [markdown]
# Имеем полином 3 степени.
# - a = -4
# - b = 0
# - c = -1
# - d = -1

# %% [markdown]
# Нарисовать график для полинома.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

def func1(x):
    return -4*x**3-x-1
  
# создаем вектор x
x1 = np.linspace(-3.0, 3.0, 100)
# на основе вектора x строим значения для вектора y
y1 = [func1(x1[i]) for i in range(len(x1))]

plt.plot(x1, y1)
plt.title('График функции')
plt.ylabel('y')
plt.xlabel('x')

plt.show()

# %% [markdown]
# **Задание 3**.
# Для заданных функций найти подходящий график (не все функции имеют график):
# $\frac{3}{4}x-1$,  $\frac{3}{4}x+2$, $2-2x$, $2+2x$, $\frac{1}{4}(x+1)^{2}-2 $, $\frac{1}{4}(x-1)^2-2$, $(x-1)(x-3)$, $(x+1)(x+3)$, $2-x^2$, $2-\frac{1}{4}x^2$

# %% [markdown]
# ![alt text](https://pp.userapi.com/c855532/v855532908/aadd4/uWjIZGDfw0s.jpg)

# %% [markdown]
# Называю функции слева направо, сверху вниз.
#
# Номер функции - номер графика
# - 1 - 5
# - 2 - нет графика, но он похож на предыдущий
# - 3 - 1
# - 4 - похожа на предыдущую, но наклонена в другую сторону
# - 5 - 4
# - 6 - похож на предыдущий, но смещен вправо
# - 7 - похож на следующий, но смещен влево
# - 8 - 6
# - 9 - 3
# - 10 - 2

# %%
# Comment if func is not needed
functions = {
    '$y = 3/4x - 1$': lambda x: 3/4*x - 1,
    '$y = 3/4x + 2$': lambda x: 3/4*x + 2,
    '$y = 2 - 2x$': lambda x: 2 - 2*x,
    '$y = 2 + 2x$': lambda x: 2 + 2*x,
    '$y = 1/4(x + 1)^2 - 2$': lambda x: 1/4*(x + 1)**2 - 2,
    '$y = 1/4(x - 1)^2 - 2$': lambda x: 1/4*(x - 1)**2 - 2,
    '$y = (x - 1)(x - 3)$': lambda x: (x - 1)*(x - 3),
    '$y = (x + 1)(x + 3)$': lambda x: (x + 1)*(x + 3),
    '$y = 2 - x^2$': lambda x: 2 - x**2,
    '$y = 2 - 1/4x^2$': lambda x: 2 - 1/4*x**2
}  

x = np.linspace(-3.0, 3.0, 100)

plt.figure(figsize=(12, 12))

for func in functions.values():
    plt.plot(x, [func(x[i]) for i in range(len(x))])
    plt.title('Графики функций')
    plt.xlabel('x')
    plt.ylabel('y')

    
plt.axhline(color='black')
plt.axvline(color='black')
plt.legend(functions.keys(), loc=1)
plt.grid()
plt.show()

# %% [markdown]
# **Задание 4.** Найти минимальную степень следующего полинома:
#
# ![alt text](https://pp.userapi.com/c855532/v855532908/aadcd/PZdPYTQT02A.jpg)

# %% [markdown]
# Максимальная степень 5, т.к. функция пересекает ось OX 5 раз.
#
# Для поиска минимальной степени, попробуем рассуждать логически:
#
# Если минимальная степень = 0, тогда тогда наша функция не может пересекать начало координат при отличных от ноля коэффициентах. Однако, если коэффициент при $x^0$ будет равен 0, то и график будет пересекать начало координат. Следовательно минимальная степень функции = 0

# %% [markdown]
# **Задания повышенного уровня**

# %% [markdown]
# 1. Почему следующие функции не являются полиномиальными?
# $$y=5x^{-2}+1$$
# $$y=3x^{1/2}+2$$
# $$y=(5x+1)/(3x)$$

# %% [markdown]
# Из определения, целая рациональная функция (также полиномиальная функция) имеет вид
# $$f(x) = \sum\limits_{i=0}^n a_ix^i$$
# где: $n \in \mathbb{N}$, $a_n, a_{n-1}, ... a_0 \in \mathbb{R}$ , $a_n \neq 0$
#
# Во всех случаях степень при x не относится к натуральным числам.

# %% [markdown]
# 2. Найдите наибольшее и наименьшее значение функции $y = x^3 + 2x^2 + x + 3 $ на отрезке [-4;-1].

# %%
x = np.linspace(-4, -1, 100)

# %%
y = [x[i]**3 + 2*x[i]**2 + x[i] + 3 for i in range(len(x))]

# %%
print('Минимум функции равен {} при x равном {} \nМаксимум функции равен {} при x равном {}'\
      .format(np.min(y), x[np.argmin(y)], np.max(y), x[np.argmax(y)]))
# Out:
# Минимум функции равен -33.0 при x равном -4.0
# Максимум функции равен 3.0 при x равном -1.0

# %% [markdown]
# Проверим

# %%
plt.plot(x, y)
plt.grid()
plt.axhline(color='black')
plt.axvline(color='black')
plt.show()

# %% [markdown]
# 3. Пример линейной регрессии - это применение полиномов на практике. В следующем примере дан датасет x, y, сгенерированный рандомно. Мы можем использовать линейную регрессию, чтобы предсказать значение переменной y от x.

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression

np.random.seed(0)
x = 2 - 3 * np.random.normal(0, 1, 20)
y = x - 2 * (x ** 2) + 0.5 * (x ** 3) + np.random.normal(-3, 3, 20)

# transforming the data to include another axis
x = x[:, np.newaxis]
y = y[:, np.newaxis]

model = LinearRegression()
model.fit(x, y)
y_pred = model.predict(x)

plt.scatter(x, y, s=10)
plt.plot(x, y_pred, color='r')
plt.show()

# %% [markdown]
# В данном примере найден полином первой степени. Как можно улучшить данную модель? Написать пример.

# %% [markdown]
# Очевидно, что лучшим решением будет подбор полинолма с большей степенью. Создадим датасет из степеней x и свободного члена.

# %%
approx_x = np.array([x[i]**pwr for i in range(len(x)) for pwr in range(0,4)])
approx_x = approx_x.reshape(20,4)

# %%
new_regression = LinearRegression()

# %%
new_regression.fit(approx_x, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
y_pred_aprox = new_regression.predict(approx_x)

# %%
plt.scatter(x, y, s=10)
plt.plot(x, y_pred_aprox.reshape(20,1), 'o', color='r')
plt.show()
