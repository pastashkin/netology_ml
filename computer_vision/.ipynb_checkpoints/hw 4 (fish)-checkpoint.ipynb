# %% [markdown]
# # The Nature Conservancy Fisheries Monitoring

# %% [markdown]
# https://www.kaggle.com/c/the-nature-conservancy-fisheries-monitoring

# %%
# %matplotlib inline
import cv2
import random
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import tensorflow as tf
from tensorflow import keras
import re

# %% [markdown]
# # Загружаем разметку

# %%
import os
import json
from glob import glob

TRAIN_PREFIX = '../input/the-nature-conservancy-fisheries-monitoring/train/'

def load_boxes():
    boxes = dict()
    for path in glob('../input/fish-boxes/*.json'):
        label = os.path.basename(path).split('_', 1)[0]
        with open(path) as src:
            boxes[label] = json.load(src)
            for annotation in boxes[label]:
                basename = os.path.basename(annotation['filename'])
                annotation['filename'] = os.path.join(TRAIN_PREFIX, label.upper(), basename)
            for annotation in boxes[label]:
                for rect in annotation['annotations']:
                    rect['x'] += rect['width'] / 2
                    rect['y'] += rect['height'] / 2
    return boxes

def draw_boxes(annotation, rectangles=None, image_size=None):
    label_rect = False
    def _draw(img, rectangles, scale_x, scale_y, color=(0, 255, 0)):
        for rect in rectangles:
            pt1 = (int((rect['x'] - rect['width'] / 2) * scale_x),
                   int((rect['y'] - rect['height'] / 2) * scale_y))
            pt2 = (int((rect['x'] + rect['width'] / 2) * scale_x),
                   int((rect['y'] + rect['height'] / 2) * scale_y))
            img = cv2.rectangle(img.copy(), pt1, pt2, 
                                color=color, thickness=4)
            if label_rect:
                img = cv2.putText(img.copy(), str(rect['fishtype'] + ': ' + str(rect['fishconf'])), (pt1[0],pt1[1]), fontFace=cv2.FONT_HERSHEY_SIMPLEX, fontScale=1.2, color=(0,255,255), lineType=1, thickness=3)        
        return img
    
    scale_x, scale_y = 1., 1.
    
    img = cv2.imread(annotation['filename'], cv2.IMREAD_COLOR)[...,::-1]
    if image_size is not None:
        scale_x = 1. * image_size[0] / img.shape[1]
        scale_y = 1. * image_size[1] / img.shape[0]
        img = cv2.resize(img, image_size)
        
    img = _draw(img, annotation['annotations'], scale_x, scale_y)
    
    if rectangles is not None:
        label_rect = True
        img = _draw(img, rectangles, 1., 1., (255, 0, 0))

    return img

# %% [markdown]
# ### Визуализируем разметку

# %%
boxes = load_boxes()  # разметка детекций

# %%
pd.DataFrame([(k, len(v)) for k, v in boxes.items()], columns=['class', 'count'])
# Out:
#    class  count
# 0    dol    117
# 1  shark    176
# 2    bet    200
# 3    lag     67
# 4    yft    734
# 5    alb   1719

# %%
plt.figure(figsize=(6, 6), dpi=120)
img = draw_boxes(boxes['lag'][21])
plt.imshow(img)
plt.title('{}x{}'.format(*img.shape));

# %% [markdown]
# ### Распределение размеров разметки

# %%
annotations = sum([box['annotations']
                  for box in sum(boxes.values(), [])], [])

widths = [rect['width'] for rect in annotations]
heights = [rect['height'] for rect in annotations]

plt.hist(widths)
plt.hist(heights);

# %% [markdown]
# # Экстрактор признаков

# %%
IMG_HEIGHT = 750
IMG_WIDTH = 1200

features = keras.applications.vgg16.VGG16(include_top=False,
                                          weights='imagenet',
                                          input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))

feature_tensor = features.layers[-1].output

# дообучаем последние 5 слоев
for layer in features.layers[:-5]:
    layer.trainable = False
# Out:
# ...
# 58892288/58889256 [==============================] - 1s 0us/step

# %% [markdown]
# # Сетка якорей (anchor grid)

# %%
FEATURE_SHAPE = (feature_tensor.shape[1].value,
                 feature_tensor.shape[2].value)

GRID_STEP_H = IMG_HEIGHT / FEATURE_SHAPE[0]
GRID_STEP_W = IMG_WIDTH / FEATURE_SHAPE[1]

ANCHOR_WIDTH = 150.
ANCHOR_HEIGHT = 150. 

ANCHOR_CENTERS = np.mgrid[GRID_STEP_H/2:IMG_HEIGHT:GRID_STEP_H,
                          GRID_STEP_W/2:IMG_WIDTH:GRID_STEP_W]

# %%
def iou(rect, x_scale, y_scale, anchor_x, anchor_y,
        anchor_w=ANCHOR_WIDTH, anchor_h=ANCHOR_HEIGHT):
    
    rect_x1 = (rect['x'] - rect['width'] / 2) * x_scale
    rect_x2 = (rect['x'] + rect['width'] / 2) * x_scale
    
    rect_y1 = (rect['y'] - rect['height'] / 2) * y_scale
    rect_y2 = (rect['y'] + rect['height'] / 2) * y_scale
    
    anch_x1, anch_x2 = anchor_x - anchor_w / 2, anchor_x + anchor_w / 2
    anch_y1, anch_y2 = anchor_y - anchor_h / 2, anchor_y + anchor_h / 2
    
    dx = (min(rect_x2, anch_x2) - max(rect_x1, anch_x1))
    dy = (min(rect_y2, anch_y2) - max(rect_y1, anch_y1))
    
    intersection = dx * dy if (dx > 0 and dy > 0) else 0.
    
    anch_square = (anch_x2 - anch_x1) * (anch_y2 - anch_y1)
    rect_square = (rect_x2 - rect_x1) * (rect_y2 - rect_y1)
    union = anch_square + rect_square - intersection
    
    return intersection / union

def encode_anchors(annotation, img_shape, iou_thr=0.5, fishtype=None):
    encoded = np.zeros(shape=(FEATURE_SHAPE[0],
                              FEATURE_SHAPE[1], 13), dtype=np.float32)
    x_scale = 1. * IMG_WIDTH / img_shape[1]
    y_scale = 1. * IMG_HEIGHT / img_shape[0]
    for rect in annotation['annotations']:
        scores = []
        for row in range(FEATURE_SHAPE[0]):
            for col in range(FEATURE_SHAPE[1]):
                anchor_x = ANCHOR_CENTERS[1, row, col]
                anchor_y = ANCHOR_CENTERS[0, row, col]
                score = iou(rect, x_scale, y_scale, anchor_x, anchor_y)
                scores.append((score, anchor_x, anchor_y, row, col))
        
        scores = sorted(scores, reverse=True)
        if scores[0][0] < iou_thr:
            scores = [scores[0]]  # default anchor
        else:
            scores = [e for e in scores if e[0] > iou_thr]

        for score, anchor_x, anchor_y, row, col in scores:
            dx = (anchor_x - rect['x'] * x_scale) / ANCHOR_WIDTH
            dy = (anchor_y - rect['y'] * y_scale) / ANCHOR_HEIGHT
            dw = (ANCHOR_WIDTH - rect['width'] * x_scale) / ANCHOR_WIDTH
            dh = (ANCHOR_HEIGHT - rect['height'] * y_scale) / ANCHOR_HEIGHT
            encoded[row, col] = [1., dx, dy, dw, dh,
                                 fishtype[0],
                                 fishtype[1],
                                 fishtype[2],
                                 fishtype[3],
                                 fishtype[4],
                                 fishtype[5],
                                 fishtype[6],
                                 fishtype[7]]
            
    return encoded

def _sigmoid(x):
    return 1. / (1. + np.exp(-x))

def decode_prediction(prediction, conf_thr=0.1):
    rectangles = []
    fish_dict = {
        0: 'ALB',
        1: 'BET',
        2: 'DOL',
        3: 'LAG',
        4: 'NoF',
        5: 'OTHER',
        6: 'SHARK',
        7: 'YFT'
    }
    
    for row in range(FEATURE_SHAPE[0]):
        for col in range(FEATURE_SHAPE[1]):
            logit, dx, dy, dw, dh, ALB, BET, DOL, LAG, NoF, OTHER, SHARK, YFT = prediction[row, col]
            conf = _sigmoid(logit)
            fish = [ALB, BET, DOL, LAG, NoF, OTHER, SHARK, YFT]
            if conf > conf_thr:
                anchor_x = ANCHOR_CENTERS[1, row, col]
                anchor_y = ANCHOR_CENTERS[0, row, col]
                rectangles.append({'x': anchor_x - dx * ANCHOR_WIDTH,
                                   'y': anchor_y - dy * ANCHOR_HEIGHT,
                                   'width': ANCHOR_WIDTH - dw * ANCHOR_WIDTH,
                                   'height': ANCHOR_HEIGHT - dh * ANCHOR_HEIGHT,
                                   'conf': conf,
                                   'fishtype': fish_dict[np.argmax(fish)],
                                   'fishconf': np.round(_sigmoid(fish[np.argmax(fish)]), 5),
                                   'fish_arr': fish
                                  })
    return rectangles

# %% [markdown]
# ### Валидация енкодинга/декодинга

# %%
example = boxes['alb'][178]

encoded = encode_anchors(example, (IMG_HEIGHT, IMG_WIDTH), 1, [1., 0., 0., 0., 0., 0., 0., 0.])

decoded = decode_prediction(encoded, conf_thr=0.5)
#decoded = sorted(decoded, key = lambda e: -e['conf'])

plt.figure(figsize=(6, 6), dpi=120)
plt.imshow(draw_boxes(example, decoded[:10]))

# %% [markdown]
# ## Функция потерь

# %%
K = tf.keras.backend
def confidence_loss(y_true, y_pred):
    conf_loss = K.binary_crossentropy(y_true[..., 0], 
                                      y_pred[..., 0],
                                      from_logits=True)
    return conf_loss

def fish_loss(y_true, y_pred):
    fish_err = K.categorical_crossentropy(y_true[..., -8:],
                                          y_pred[..., -8:],
                                          from_logits=True)
    return fish_err

def smooth_l1(y_true, y_pred):
    abs_loss = K.abs(y_true[..., 1:5] - y_pred[..., 1:5])
    square_loss = 0.5 * K.square(y_true[..., 1:5] - y_pred[..., 1:5])
    mask = K.cast(K.greater(abs_loss, 1.), 'float32')
    total_loss = (abs_loss - 0.5) * mask + 0.5 * square_loss * (1. - mask)
    return K.sum(total_loss, axis=-1)

def total_loss(y_true, y_pred, neg_pos_ratio=3):
    batch_size = K.shape(y_true)[0]
    
    y_true = K.reshape(y_true, (batch_size, -1, 13))
    y_pred = K.reshape(y_pred, (batch_size, -1, 13))
    
    # fish loss
    fish_err = fish_loss(y_true, y_pred)

     # confidence loss
    conf_loss = confidence_loss(y_true, y_pred)
    
    # smooth l1 loss
    loc_loss = smooth_l1(y_true, y_pred)
    
    # positive examples loss
    pos_conf_loss = K.sum(conf_loss * y_true[..., 0], axis=-1)
    pos_loc_loss = K.sum(loc_loss * y_true[..., 0], axis=-1)
    
    # negative examples loss
    anchors = K.shape(y_true)[1]
    num_pos = K.sum(y_true[..., 0], axis=-1)
    num_pos_avg = K.mean(num_pos)
    num_neg = K.min([neg_pos_ratio * (num_pos_avg) + 1., K.cast(anchors, 'float32')])
    
    # hard negative mining
    neg_conf_loss, _ = tf.nn.top_k(conf_loss * (1. - y_true[..., 0]),
                                   k=K.cast(num_neg, 'int32'))

    neg_conf_loss = K.sum(neg_conf_loss, axis=-1)
    
    # total conf loss
    total_conf_loss = (neg_conf_loss + pos_conf_loss) / (num_neg + num_pos + 1e-32)
    loc_loss = pos_loc_loss / (num_pos + 1e-32)
    
    #fish loss total error
    fish_total_err = K.sum(fish_err * y_true[..., 0], axis=-1)
    
    return total_conf_loss + 0.5 * loc_loss + 1.5 * fish_total_err

# %% [markdown]
# ## Загрузка данных

# %%
def fish_encoder(fish, encode_type='fish_by_num'):
    fish_by_num = {0: 'ALB', 1: 'BET', 2: 'DOL', 3: 'LAG', 
                   4: 'NoF', 5: 'OTHER',6: 'SHARK', 7: 'YFT'}
    if encode_type == 'fish_by_num':
        return fish_by_num[fish]
    if encode_type == 'fish_by_boxname':
        return fish.upper()

def load_img(path, target_size=(IMG_WIDTH, IMG_HEIGHT)):
    fish_dict = {
        'ALB': [1., 0., 0., 0., 0., 0., 0., 0.],
        'BET': [0., 1., 0., 0., 0., 0., 0., 0.],
        'DOL': [0., 0., 1., 0., 0., 0., 0., 0.],
        'LAG': [0., 0., 0., 1., 0., 0., 0., 0.],
        'NoF': [0., 0., 0., 0., 1., 0., 0., 0.],
        'OTHER': [0., 0., 0., 0., 0., 1., 0., 0.],
        'SHARK': [0., 0., 0., 0., 0., 0., 1., 0.],
        'YFT': [0., 0., 0., 0., 0., 0., 0., 1.]
    }
        
    img = cv2.imread(path, cv2.IMREAD_COLOR)[...,::-1]
    img_shape = img.shape
    img_resized = cv2.resize(img, target_size)
    fish_type = np.array(fish_dict[re.split('/', path)[-2]])
    return img_shape, keras.applications.vgg16.preprocess_input(img_resized.astype(np.float32)), fish_type.astype(np.float32)

def data_generator(boxes, batch_size=32):
    boxes = sum(boxes.values(), [])
    while True:
        random.shuffle(boxes)
        for i in range(len(boxes)//batch_size):
            X, y = [], []
            for j in range(i*batch_size,(i+1)*batch_size):
                img_shape, img, fish_type = load_img(boxes[j]['filename'])
                y.append(encode_anchors(boxes[j], img_shape, 0.5, fish_type))
                X.append(img)
            yield np.array(X), np.array(y)

# %% [markdown]
# ## Добавляем выход детектора

# %%
output = keras.layers.BatchNormalization()(feature_tensor)

output = keras.layers.Conv2D(13,
                             kernel_size=(1, 1), 
                             activation='linear',
                             kernel_regularizer='l2')(output)

model = keras.models.Model(inputs=features.inputs, outputs=output)

# %% [markdown]
# ## Обучение

# %%
model.load_weights('../input/fish-weights/final_weights.hdf5')

# %%
# No more train
adam = keras.optimizers.Adam(lr=3e-5, decay=1e-6)
model.compile(optimizer=adam, 
              loss=total_loss,
              metrics=[confidence_loss, fish_loss])

# %%
# Uncomment to train
batch_size = 5
steps_per_epoch = sum(map(len, boxes.values()), 0) / batch_size

gen = data_generator(boxes, batch_size=batch_size)

checkpoint = keras.callbacks.ModelCheckpoint(
    '../working/weights.hdf5',
    monitor='loss',
    verbose=1,  
    save_best_only=True, 
    save_weights_only=True,
    mode='auto', save_freq=10)

model.fit_generator(generator=gen,
                    steps_per_epoch=steps_per_epoch,
                    epochs=20,
                    callbacks=[checkpoint])

# %%
model.save_weights('../working/fine_final_weights.hdf5')

# %%
#model.load_weights('../input/fish-weights/final_weights.hdf5')

# %% [markdown]
# ## Результат работы детектора

# %%
example = boxes['alb'][42]

_, sample_img, _ = load_img(example['filename'])
pred = model.predict(np.array([sample_img,]))[0]

decoded = decode_prediction(pred, conf_thr=0.1)
decoded = sorted(decoded, key=lambda e: -e['conf'])

plt.figure(figsize=(6, 6), dpi=120)
img = draw_boxes(example, decoded[:1], (IMG_WIDTH, IMG_HEIGHT))
plt.imshow(img)
plt.title('{}x{}'.format(*img.shape));

# %% [markdown]
# ## Агрегация результатов

# %%
TEST_PREFIX = '../input/full-test/test_stg2/test_stg2/*.jpg'

# %%
def draw_test_boxes(annotation, rectangles=None, image_size=None):
    label_rect = False
    def _draw(img, rectangles, scale_x, scale_y, color=(0, 255, 0)):
        for rect in rectangles:
            pt1 = (int((rect['x'] - rect['width'] / 2) * scale_x),
                   int((rect['y'] - rect['height'] / 2) * scale_y))
            pt2 = (int((rect['x'] + rect['width'] / 2) * scale_x),
                   int((rect['y'] + rect['height'] / 2) * scale_y))
            img = cv2.rectangle(img.copy(), pt1, pt2, 
                                color=color, thickness=4)
            if label_rect:
                img = cv2.putText(img.copy(), str(rect['fishtype'] + ': ' + str(rect['fishconf'])), (pt1[0],pt1[1]), fontFace=cv2.FONT_HERSHEY_SIMPLEX, fontScale=1.2, color=(0,255,255), lineType=1, thickness=3)        
        return img
    
    scale_x, scale_y = 1., 1.
    
    img = cv2.imread(annotation, cv2.IMREAD_COLOR)[...,::-1]
    if image_size is not None:
        scale_x = 1. * image_size[0] / img.shape[1]
        scale_y = 1. * image_size[1] / img.shape[0]
        img = cv2.resize(img, image_size)
        
    img = _draw(img, rectangles, scale_x, scale_y)
    
    if rectangles is not None:
        label_rect = True
        img = _draw(img, rectangles, 1., 1., (255, 0, 0))

    return img

def load_test_img(path, target_size=(IMG_WIDTH, IMG_HEIGHT)):
    img = cv2.imread(path, cv2.IMREAD_COLOR)[...,::-1]
    img_resized = cv2.resize(img, target_size)
    img_to_predict = keras.applications.vgg16.preprocess_input(img_resized.astype(np.float32))
    pred = model.predict(np.array([img_to_predict,]))[0]
    decoded = decode_prediction(pred, conf_thr=0.1)
    decoded = sorted(decoded, key=lambda e: -e['conf'])
    img = draw_test_boxes(path, decoded[:1], (IMG_WIDTH, IMG_HEIGHT))
    plt.imshow(img)

# %%
def fish_test_predict(path):
    img = cv2.imread(path, cv2.IMREAD_COLOR)[...,::-1]
    img_resized = cv2.resize(img, (IMG_WIDTH, IMG_HEIGHT))
    img_to_predict = keras.applications.vgg16.preprocess_input(img_resized.astype(np.float32))
    pred = model.predict(np.array([img_to_predict,]))[0]
    decoded = decode_prediction(pred, conf_thr=0.05)
    decoded = sorted(decoded, key=lambda e: -e['conf'])
    if decoded == []:
        fishtype = 'NoF'
        fishconf = 1.
        fish = [0., 0., 0., 0., 1., 0., 0., 0.]
    else:
        fishtype = decoded[:1][0]['fishtype']
        fishconf = decoded[:1][0]['fishconf']
        fish = list(map(_sigmoid, decoded[:1][0]['fish_arr']))
        
        
    img_name = re.split('/', path)[-1]
    return img_name, fishtype, fishconf, fish

fish_test_predict(glob(TEST_PREFIX)[85])
# Out:
# ('image_09027.jpg',
#  'ALB',
#  0.98771,
#  [0.9877137982127576,
#   0.22779227067885105,
#   0.37399364970213306,
#   0.19364277243110897,
#   0.1095908393088324,
#   0.1094930427096337,
#   0.43735844427214843,
#   0.4286477847751336])

# %%
load_test_img(glob(TEST_PREFIX)[109])

# %%
import pandas as pd
from tqdm import tqdm_notebook 
submission = [[]*x for x in range(9)]
columns = ['image','ALB','BET','DOL','LAG','NoF','OTHER','SHARK','YFT']
fish_dict = {
    'ALB': [1., 0., 0., 0., 0., 0., 0., 0.],
    'BET': [0., 1., 0., 0., 0., 0., 0., 0.],
    'DOL': [0., 0., 1., 0., 0., 0., 0., 0.],
    'LAG': [0., 0., 0., 1., 0., 0., 0., 0.],
    'NoF': [0., 0., 0., 0., 1., 0., 0., 0.],
    'OTHER': [0., 0., 0., 0., 0., 1., 0., 0.],
    'SHARK': [0., 0., 0., 0., 0., 0., 1., 0.],
    'YFT': [0., 0., 0., 0., 0., 0., 0., 1.]
}

# %%
for pic in tqdm_notebook(glob(TEST_PREFIX)):
    submission[0].append(fish_test_predict(pic)[0])
    this_fish_array = fish_test_predict(pic)[3]
    for i in range(1,9):
        submission[i].append(this_fish_array[i-1])

# %%
# for pic in tqdm_notebook(glob(TEST_PREFIX)):
#     submission[0].append(fish_test_predict(pic)[0])
#     this_fish_array = fish_dict[fish_test_predict(pic)[1]]
#     this_fish_array[np.argmax(this_fish_array)] = fish_test_predict(pic)[2]
#     for i in range(1,9):
#         submission[i].append(this_fish_array[i-1])

# %%
submission_df = pd.DataFrame(np.transpose(submission), columns=columns)
submission_df.head()

# %%
submission_df.to_csv('../working/fishsub.csv', index=False)

# %% [markdown]
# ### Результаты
#
# Результаты не очень - я в конце списка кеггл.
# Много ошибок было не на классификации, а на детекции. Следовательно в финале очень много NoF значений.
#
# Есть еще что можно докрутить. Например, разделить задачу на детекцию и классификацию - накропать рыб, докрутить аугментацию, сбалансировать классы.

# %%
from IPython.display import Image
# score 18.56958
Image('./data/fish_score.png')
