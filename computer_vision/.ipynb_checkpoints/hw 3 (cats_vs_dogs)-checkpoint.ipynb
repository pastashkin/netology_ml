# %% [markdown]
# # Dogs vs. Cats

# %% [markdown]
# https://www.kaggle.com/c/dogs-vs-cats-redux-kernels-edition

# %%
import numpy as np
from tensorflow import keras
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# %%
IMG_SIZE = (224, 224)  # размер входного изображения сети

# %% [markdown]
# ## Функции загрузки данных

# %%
import re
from random import shuffle
from glob import glob

train_files = glob('../input/train/*.jpg')
test_files = glob('../input/test/*.jpg')

# загружаем входное изображение и предобрабатываем
def load_image(path, target_size=IMG_SIZE):
    img = load_img(path, target_size=target_size)  # загрузка и масштабирование изображения
    array = img_to_array(img)
    return preprocess_input(array)  # предобработка для VGG16

# генератор для последовательного чтения обучающих данных с диска
def fit_generator(files, batch_size=32):
    while True:
        shuffle(files)
        for k in range(len(files) // batch_size):
            i = k * batch_size
            j = i + batch_size
            if j > len(files):
                j = - j % len(files)
            x = np.array([load_image(path) for path in files[i:j]])
            y = np.array([1. if re.match('.*/dog\.\d', path) else 0. for path in files[i:j]])
            yield (x, y)

# генератор последовательного чтения тестовых данных с диска
def predict_generator(files):
    while True:
        for path in files:
            yield np.array([load_image(path)])

# %% [markdown]
# ## Визуализируем примеры для обучения

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(20, 20))
for i, path in enumerate(train_files[:10], 1):
    subplot = fig.add_subplot(i // 5 + 1, 5, i)
    plt.imshow(plt.imread(path));
    subplot.set_title('%s' % path.split('/')[-1]);

# %% [markdown]
# ## Загружаем предобученную модель

# %%
# base_model -  объект класса keras.models.Model (Functional Model)
base_model = VGG16(include_top = False,
                   weights = 'imagenet',
                   input_shape = (IMG_SIZE[0], IMG_SIZE[1], 3))

# %%
# фиксируем все веса предобученной сети
for layer in base_model.layers:
    layer.trainable = False

# %%
base_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_24 (InputLayer)        [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# ## Добавляем пару сверток и полносвязный слой

# %%
x = base_model.layers[-4].output
x = keras.layers.Conv2D(kernel_size = (3,3), filters = 512, activation='sigmoid', kernel_regularizer=keras.regularizers.l1(1e-4))(x)
x = keras.layers.Conv2D(kernel_size = (5,5), filters = 256, activation='sigmoid', kernel_regularizer=keras.regularizers.l1(1e-4))(x)
x = keras.layers.Flatten()(x)
x = keras.layers.Dense(1,  # один выход
                activation='sigmoid',  # функция активации  
                kernel_regularizer=keras.regularizers.l1(1e-4))(x)
model = Model(inputs=base_model.input, outputs=x)

# %%
# фиксируем все веса предобученной сети, но не все
for layer in model.layers:
    layer.trainable = False
for layer in model.layers[-7:]:
    layer.trainable = True

# %% [markdown]
# ## Выводим архитектуру модели

# %%
model.summary()
# Out:
# Model: "model_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_24 (InputLayer)        [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 12, 12, 512)       2359808
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 8, 8, 256)         3277056
# _________________________________________________________________
# flatten_19 (Flatten)         (None, 16384)             0
# _________________________________________________________________
# dense_20 (Dense)             (None, 1)                 16385
# =================================================================
# Total params: 15,648,321
# Trainable params: 10,372,865
# Non-trainable params: 5,275,456
# _________________________________________________________________

# %% [markdown]
# ## Компилируем модель и запускаем обучение

# %%
# снижаем шаг обучения
opt = keras.optimizers.Adam(lr=0.00003, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.01, amsgrad=False)
model.compile(optimizer=opt, 
                loss='binary_crossentropy',  # функция потерь binary_crossentropy (log loss)
              metrics=['accuracy'])

# %%
shuffle(train_files)  # перемешиваем обучающую выборку

train_val_split = 100  # число изображений в валидационной выборке

validation_data = next(fit_generator(train_files[:train_val_split], train_val_split))

# запускаем процесс обучения
model.fit_generator(fit_generator(train_files[train_val_split:]),  # данные читаем функцией-генератором
        steps_per_epoch=10,  # число вызовов генератора за эпоху
        epochs=200,  # число эпох обучения
        validation_data=validation_data)
# Out:
# Epoch 1/200
# 10/10 [==============================] - 6s 569ms/step - loss: 6.6546 - acc: 0.4906 - val_loss: 6.6604 - val_acc: 0.4100
# Epoch 2/200
# 10/10 [==============================] - 1s 127ms/step - loss: 6.5531 - acc: 0.6219 - val_loss: 6.5172 - val_acc: 0.7700
# Epoch 3/200
# 10/10 [==============================] - 1s 128ms/step - loss: 6.4810 - acc: 0.7937 - val_loss: 6.4584 - val_acc: 0.8300
# Epoch 4/200
# 10/10 [==============================] - 1s 128ms/step - loss: 6.4357 - acc: 0.8313 - val_loss: 6.4102 - val_acc: 0.8100
# Epoch 5/200
# 10/10 [==============================] - 1s 143ms/step - loss: 6.3605 - acc: 0.8719 - val_loss: 6.3770 - val_acc: 0.8800
# Epoch 6/200
# 10/10 [==============================] - 2s 155ms/step - loss: 6.3243 - acc: 0.8813 - val_loss: 6.3386 - val_acc: 0.8900
# Epoch 7/200
# 10/10 [==============================] - 2s 154ms/step - loss: 6.2725 - acc: 0.8750 - val_loss: 6.2910 - val_acc: 0.9100
# Epoch 8/200
# 10/10 [==============================] - 2s 158ms/step - loss: 6.2297 - acc: 0.9344 - val_loss: 6.2440 - val_acc: 0.9000
# Epoch 9/200
# 10/10 [==============================] - 2s 151ms/step - loss: 6.2062 - acc: 0.9031 - val_loss: 6.2107 - val_acc: 0.9100
# Epoch 10/200
# 10/10 [==============================] - 2s 155ms/step - loss: 6.1923 - acc: 0.8938 - val_loss: 6.1776 - val_acc: 0.9300
# Epoch 11/200
# 10/10 [==============================] - 2s 152ms/step - loss: 6.1160 - acc: 0.9156 - val_loss: 6.1496 - val_acc: 0.9400
# Epoch 12/200
# 10/10 [==============================] - 2s 161ms/step - loss: 6.1176 - acc: 0.9094 - val_loss: 6.1264 - val_acc: 0.9200
# Epoch 13/200
# 10/10 [==============================] - 2s 163ms/step - loss: 6.0901 - acc: 0.9250 - val_loss: 6.1008 - val_acc: 0.9500
# Epoch 14/200
# 10/10 [==============================] - 2s 163ms/step - loss: 6.1187 - acc: 0.8719 - val_loss: 6.0723 - val_acc: 0.9300
# Epoch 15/200
# 10/10 [==============================] - 2s 152ms/step - loss: 6.0466 - acc: 0.9312 - val_loss: 6.0466 - val_acc: 0.9500
# Epoch 16/200
# 10/10 [==============================] - 2s 157ms/step - loss: 6.0223 - acc: 0.9469 - val_loss: 6.0242 - val_acc: 0.9400
# Epoch 17/200
# 10/10 [==============================] - 2s 157ms/step - loss: 6.0226 - acc: 0.9406 - val_loss: 6.0079 - val_acc: 0.9400
# Epoch 18/200
# 10/10 [==============================] - 2s 154ms/step - loss: 6.0242 - acc: 0.9375 - val_loss: 5.9844 - val_acc: 0.9600
# Epoch 19/200
# 10/10 [==============================] - 2s 156ms/step - loss: 6.0011 - acc: 0.9187 - val_loss: 5.9735 - val_acc: 0.9400
# Epoch 20/200
# 10/10 [==============================] - 2s 161ms/step - loss: 5.9701 - acc: 0.9469 - val_loss: 5.9528 - val_acc: 0.9600
# Epoch 21/200
# 10/10 [==============================] - 2s 156ms/step - loss: 5
200
# 10/10 [==============================] - 2s 153ms/step - loss: 5.3968 - acc: 0.9844 - val_loss: 5.4046 - val_acc: 0.9900
# Epoch 185/200
# 10/10 [==============================] - 1s 150ms/step - loss: 5.4135 - acc: 0.9781 - val_loss: 5.4027 - val_acc: 0.9900
# Epoch 186/200
# 10/10 [==============================] - 1s 149ms/step - loss: 5.4198 - acc: 0.9812 - val_loss: 5.4002 - val_acc: 0.9900
# Epoch 187/200
# 10/10 [==============================] - 2s 152ms/step - loss: 5.4039 - acc: 0.9781 - val_loss: 5.3982 - val_acc: 0.9900
# Epoch 188/200
# 10/10 [==============================] - 1s 150ms/step - loss: 5.4147 - acc: 0.9719 - val_loss: 5.3970 - val_acc: 0.9900
# Epoch 189/200
# 10/10 [==============================] - 1s 150ms/step - loss: 5.4221 - acc: 0.9750 - val_loss: 5.3950 - val_acc: 0.9900
# Epoch 190/200
# 10/10 [==============================] - 2s 153ms/step - loss: 5.3960 - acc: 0.9812 - val_loss: 5.3932 - val_acc: 0.9900
# Epoch 191/200
# 10/10 [==============================] - 1s 148ms/step - loss: 5.3902 - acc: 0.9875 - val_loss: 5.3936 - val_acc: 0.9900
# Epoch 192/200
# 10/10 [==============================] - 2s 156ms/step - loss: 5.3894 - acc: 0.9875 - val_loss: 5.3902 - val_acc: 0.9900
# Epoch 193/200
# 10/10 [==============================] - 1s 147ms/step - loss: 5.3980 - acc: 0.9750 - val_loss: 5.3879 - val_acc: 0.9900
# Epoch 194/200
# 10/10 [==============================] - 2s 153ms/step - loss: 5.4014 - acc: 0.9844 - val_loss: 5.3868 - val_acc: 0.9900
# Epoch 195/200
# 10/10 [==============================] - 1s 149ms/step - loss: 5.3869 - acc: 0.9844 - val_loss: 5.3856 - val_acc: 0.9900
# Epoch 196/200
# 10/10 [==============================] - 1s 148ms/step - loss: 5.3793 - acc: 0.9812 - val_loss: 5.3851 - val_acc: 0.9900
# Epoch 197/200
# 10/10 [==============================] - 2s 156ms/step - loss: 5.3837 - acc: 0.9812 - val_loss: 5.3831 - val_acc: 0.9900
# Epoch 198/200
# 10/10 [==============================] - 2s 152ms/step - loss: 5.4064 - acc: 0.9750 - val_loss: 5.3807 - val_acc: 0.9900
# Epoch 199/200
# 10/10 [==============================] - 1s 148ms/step - loss: 5.3793 - acc: 0.9844 - val_loss: 5.3817 - val_acc: 0.9900
# Epoch 200/200
# 10/10 [==============================] - 1s 148ms/step - loss: 5.3961 - acc: 0.9750 - val_loss: 5.3778 - val_acc: 0.9900

# %%
model.save('cats-dogs-vgg16.hdf5')

# %% [markdown]
# ## Предсказания на проверочной выборке

# %%
pred = model.predict_generator(predict_generator(test_files), len(test_files), max_queue_size=500)

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(40, 20))
for i, (path, score) in enumerate(zip(test_files[100:][:25], pred[100:][:25]), 1):
    subplot = fig.add_subplot(i // 12 + 1, 12, i)
    plt.imshow(plt.imread(path));
    subplot.set_title('%.3f' % score);

# %% [markdown]
# ## Готовим данные для сабмита

# %%
with open('../working/submission047.csv', 'w') as dst:
    dst.write('id,label\n')
    for path, score in zip(test_files, pred):
        dst.write('%s,%f\n' % (re.search('(\d+)', path).group(0), score))

# %%
from IPython.display import Image

# %%
# score 0.10256
Image('./data/score_cats.png')
